# %%
# !unzip /content/drive/MyDrive/dataset.zip
# Out:
# Archive:  /content/drive/MyDrive/dataset.zip
#    creating: dataset/images/
#    creating: dataset/images/train/
#   inflating: dataset/images/train/0.jpg
#   inflating: dataset/images/train/12.jpg
#   inflating: dataset/images/train/146336fdcdc96b2066f199da1fb55d59.jpg
#   inflating: dataset/images/train/20240128_161935.jpg
#   inflating: dataset/images/train/20240128_161952.jpg
#   inflating: dataset/images/train/20240128_162013.jpg
#   inflating: dataset/images/train/20240128_162019.jpg
#   inflating: dataset/images/train/20240128_162032.jpg
#   inflating: dataset/images/train/20240131_150751.jpg
#   inflating: dataset/images/train/20240131_150810.jpg
#   inflating: dataset/images/train/3-great-window-styles-for-your-living-room.jpg
#   inflating: dataset/images/train/453935865.jpg
#   inflating: dataset/images/train/484844777.jpg
#   inflating: dataset/images/train/5-ideas-to-make-more-space-in-small-bedroom-intro-2.jpg
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/yolov5.zip
# Out:
# Archive:  /content/drive/MyDrive/yolov5.zip
#   inflating: yolov5/.dockerignore
#    creating: yolov5/.git/
#   inflating: yolov5/.git/config
#   inflating: yolov5/.git/description
#  extracting: yolov5/.git/HEAD
#    creating: yolov5/.git/hooks/
#   inflating: yolov5/.git/hooks/applypatch-msg.sample
#   inflating: yolov5/.git/hooks/commit-msg.sample
#   inflating: yolov5/.git/hooks/fsmonitor-watchman.sample
#   inflating: yolov5/.git/hooks/post-update.sample
#   inflating: yolov5/.git/hooks/pre-applypatch.sample
#   inflating: yolov5/.git/hooks/pre-commit.sample
#   inflating: yolov5/.git/hooks/pre-merge-commit.sample
#   inflating: yolov5/.git/hooks/prepare-commit-msg.sample
#   inflating: yolov5/.git/hooks/pre-push.sample
#   inflating: yolov5/.git/hooks/pre-rebase.sample
#   inflating: yolov5/.git/hooks/pre-receive.sample
#   inflating: yolov5/.git/hooks/push-to-checkout.sample
#   inflating: yolov5/.git/hooks/update.sample
#   inflating: yolov5/.git/index
# ...

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5n')
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/hub.py:294: UserWarning: You are about to download and run code from an untrusted repository. In a future release, this won't be allowed. To add the repository to your trusted list, change the command to {calling_fn}(..., trust_repo=False) and a command prompt will appear asking for an explicit confirmation of trust, or load(..., trust_repo=True), which will assume that the prompt is to be answered with 'yes'. You can also use load(..., trust_repo='check') which will only prompt for confirmation if the repo is not already trusted. This will eventually be the default behaviour
#   warnings.warn(
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /root/.cache/torch/hub/master.zip
# requirements: Ultralytics requirement ['gitpython>=3.1.30'] not found, attempting AutoUpdate...
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.4/196.4 kB 6.9 MB/s eta 0:00:00
# ...

# %%
# !cd yolov5 && python train.py --img 320 --batch 64 --epochs 70 --data /content/dataset.yaml --weights yolov5n.pt --workers 2
# Out:
# 2024-02-13 14:48:42.536748: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-13 14:48:42.536813: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-13 14:48:42.538384: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path='/content/yolov5/runs/train/exp/weights/last.pt', force_reload=True)

model.conf = 0.2
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /root/.cache/torch/hub/master.zip
# YOLOv5 🚀 2024-2-13 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 1760518 parameters, 0 gradients, 4.1 GFLOPs
# Adding AutoShape...

# %%
img1= "/content/dataset/images/val/window-grill-designs.jpg"
results = model(img1)

# %%
# %matplotlib inline
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
img2= "/content/dataset/images/val/window(12).jpg"
results = model(img2)

# %%
# %matplotlib inline
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
img3= "/content/dataset/images/val/wooden-window-grill-design.jpg"
results = model(img3)

# %%
# %matplotlib inline
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
img4= "/content/dataset/images/train/0.jpg"
results = model(img4)

# %%
# %matplotlib inline
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
img5= "/content/dataset/images/train/20240128_161952.jpg"
results = model(img5)

# %%
# %matplotlib inline
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
img6= "/content/dataset/images/train/20240128_162032.jpg"
results = model(img6)

# %%
# %matplotlib inline
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
img7= "/content/dataset/images/train/3-great-window-styles-for-your-living-room.jpg"
results = model(img7)

# %%
# %matplotlib inline
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
img8= "/content/dataset/images/train/5-ideas-to-make-more-space-in-small-bedroom-intro-2.jpg"
results = model(img8)

# %%
# %matplotlib inline
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
img9= "/content/dataset/images/train/453935865.jpg"
results = model(img9)

# %%
# %matplotlib inline
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
img10= "/content/dataset/images/train/House-Casement-French-Window-Grill-Price-Design-Wooden-Wood-Windows.jpg"
results = model(img10)

# %%
# %matplotlib inline
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
img11= "/content/dataset/images/train/download%20(1).jpeg"
results = model(img11)

# %%
# %matplotlib inline
plt.imshow(np.squeeze(results.render()))
plt.show()
